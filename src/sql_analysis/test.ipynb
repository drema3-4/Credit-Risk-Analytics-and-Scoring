# %%
import sqlite3
import pandas as pd

# %%
conn = sqlite3.connect("db.db")

# %%
query = """
SELECT
    name AS column_name,
    type AS data_type
FROM pragma_table_info('borrowers_score')
ORDER BY cid;
"""

# %%
pd.read_sql(query, conn)
# Out:
#    column_name data_type
# 0  borrower_id   INTEGER
# 1        score      REAL

# %%
conn.close()
